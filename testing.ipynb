# %%
from apps import *
import pandas as pd

# %%
target = [0,1]
cardinality = 10
TrainSet, idxGT = getmnist().getmnist(target, cardinality)

# %%
mnistdistance = gnist().mnistdistance(TrainSet)
pd.DataFrame(mnistdistance)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.000000  1.153846  1.000000  1.111111  1.115385  1.111111  1.137931
# 1   1.153846  0.000000  1.120000  1.111111  1.038462  1.148148  1.137931
# 2   1.000000  1.120000  0.000000  1.074074  1.076923  1.037037  1.137931
# 3   1.111111  1.111111  1.074074  0.000000  1.111111  1.074074  1.103448
# 4   1.115385  1.038462  1.076923  1.111111  0.000000  1.074074  1.068966
# 5   1.111111  1.148148  1.037037  1.074074  1.074074  0.000000  1.103448
# 6   1.137931  1.137931  1.137931  1.103448  1.068966  1.103448  0.000000
# 7   1.115385  1.076923  1.038462  1.074074  1.115385  1.111111  1.172414
# 8   1.192308  1.200000  1.120000  1.148148  1.038462  1.111111  1.137931
# 9   1.153846  1.080000  1.120000  1.148148  1.038462  1.000000  1.172414
# 10  1.076923  1.080000  1.083333  1.074074  1.076923  1.074074  1.172414
# 11  1.115385  1.120000  1.083333  1.037037  1.038462  1.074074  1.137931
# ...
